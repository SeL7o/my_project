# %%
import requests
from bs4 import BeautifulSoup
get_ipython().system('pip install selenium==2.53.6')

# %%
from selenium import webdriver

# %%
web = webdriver.Chrome()

# %%
url =("https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=US")

# %%
web.get(url)

# %%
button = web.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div/div[1]/div[2]/div/div[1]/div[1]/c-wiz[4]/section/header/div/div[2]/button')
button.click()

# %%
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
            AppleWebKit/537.36 (KHTML, like Gecko) \
            Chrome/90.0.4430.212 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
  
# user define function
# Scrape the data
def getdata(url):
    r = requests.get(url, headers=HEADERS)
    return r.text
  
  
def html_code(url):
  
    # pass the url
    # into getdata function
    soup = BeautifulSoup(web.page_source, 'html.parser')
  
    # display html code
    return (soup)
  
  
url = "https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=US"
  
soup = html_code(url)
print(soup)
# Out:
# <html dir="ltr" lang="en"><head><script async="" crossorigin="anonymous" integrity="sha384-4eVJVnSQi48XouWWBCleJxcjDMTY1Z4KmOhd0bvetv4tPVMhPa8rAthYuqSjf197" nonce="" src="https://www.gstatic.com/recaptcha/releases/CDFvp7CXAHw7k3HxO47Gm1O9/recaptcha__en.js" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js"></script><base href="https://play.google.com/"/><meta content="origin" name="referrer"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="sBw2N8uateIzRr93vmFze5MF_35vMk5F1wG04L5JcJE" name="google-site-verification"/><meta content="PJKdyVFC5jlu_l8Wo_hirJkhs1cmitmn44fgpOc3zFc" name="google-site-verification"/><link href="/opensearch.xml" rel="search" title="Google Play" type="application/opensearchdescription+xml"/><link href="//www.gstatic.com/android/market_images/web/favicon_v3.ico" 
# ...

# %%
def sc_web(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_str = ""
    cus_list = []
  
    for item in soup.find_all("div", class_="X5PpBb"):
        data_str = data_str + item.get_text()
        cus_list.append(data_str)
        data_str = ""
    return cus_list
  
  
 name_coustmor = cus_data(soup)
print(name_coustmor)
# Out:
# ['Jo Mosley', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USOlga Romanova', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USBrian Perry', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USJo Mosley', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USOlga Romanova', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USBrian Perry', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USPaul E. Drecksler', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USMichael Markman', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USOPN', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USEduardo Mathieu Rebolledo', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USKristen Albertson-Bird', 'https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USMiguel Campos', 'https://play.google.com/stor
# ...

# %%
def sc_web(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_str = ""
    cus_list = []
  
    for item in soup.find_all("div", class_="h3YV2d"):
        data_str = data_str + item.get_text()
        cus_list.append(data_str)
        data_str = ""
    return cus_list
   
reviews = cus_data(soup)
print(reviews)
# Out:
# ["Booking knows how to keep the reservation, not just make it - like a few of the hotels I reserved and had to adjust dates. Booking had it correct, but even after speaking to the manager over the phone to confirm, (since they never replied to the email sent through booking), when I arrived, they had cancelled the original but never reserved one for the new date. Booking took care of everything and it wasnt more than a 20 minute delay. This is the third time tbey've come to my rescue. Grateful!", "https://play.google.com/store/apps/details?id=com.booking&hl=en&gl=USI've used the app for years and was a loyal customer untill booking stopped to show the full price of the properties. For example you see attractive price of a property, open the page and all looks good untill you move to the payment and you see absolutely different picture: tons of fees (cleaning, property, variety of taxes and so on). So you have to open every property to figure out the price and spend a lot of time to f
# ...

# %%
import pandas as pd
  
# initialise data of lists.
data = {'Name': name_coustmor,
        'review': reviews}
  
# Create DataFrame
df = pd.DataFrame(data)
  
# Save the output.
df.to_csv('booking10.csv')
